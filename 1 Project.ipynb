# %%
# %matplotlib inline

from modsim import *
from pandas import read_csv
filename = 'data/Maine_lobster_landings_by_region.csv'
filename
# Out:
# 'data/Maine_lobster_landings_by_region.csv'

# %%
tables = read_csv(filename, header=0, index_col=0, decimal='M')
tables
# Out:
#        Southern   Midcoast   Downeast
# date
# 1964   3.406174   9.115317   8.399206
# 1965   3.611181   7.641661   7.608943
# 1966   3.987148   7.839243   8.089425
# 1967   3.429761   6.772436   6.286999
# 1968   4.166249   8.293543    8.04194
# 1969   3.972578   8.014369   7.847833
# 1970   3.872192   7.426074   6.874003
# 1971   4.084356   7.001318   6.472677
# 1972   3.604835   6.741724   5.909908
# 1973   3.450101   6.643606   6.852915
# 1974   4.148624   6.179949   5.963286
# 1975   3.787677   7.101196   5.626715
# 1976   4.064979   7.863299   7.072775
# 1977   4.263241   7.998453   6.225444
# 1978   4.566869   8.143454   6.420136
# 1979    5.52313    8.92023   7.689875
# 1980   5.925103    8.91642   7.145371
# 1981   6.792334   8.824218   7.015062
# 1982   6.405216   9.333689   6.991348
# 1983   5.632134   9.637033   6.707388
# 1984   5.448412   8.892546   5.204724
# 1985   6.005043   8.667996   5.452138
# 1986   6.278269    8.09557   5.330478
# ...

# %%
plot(tables.Southern, color= 'red')
plot(tables.Midcoast, color='blue')
plot(tables.Downeast, color='green')
